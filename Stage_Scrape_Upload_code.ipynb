# %%
import requests
import csv
from bs4 import BeautifulSoup as bs
from random import randint
from time import sleep
from urllib.parse import urljoin
import os
import snowflake.connector
from datetime import datetime
import uuid
import re
import pandas as pd
import time
from word2number import w2n  # Library to convert numbers to words

# %%
URL = 'https://www.espncricinfo.com/records/trophy/indian-premier-league-117'
sleep_delay = 5
#https://rforotb-ka22072.snowflakecomputing.com
# Snowflake connection parameters
snowflake_account = 'rforotb-ka22072'
snowflake_warehouse= 'COMPUTE_WH'
snowflake_database = 'MYCRICKET'
snowflake_schema = 'DATA1'
snowflake_user = 'comicsvibe'
snowflake_password = 'Comicsvibe123!'
snowflake_stage = 'MYSTAGE1'

# Establish Snowflake connection
conn = snowflake.connector.connect(
    account=snowflake_account,
    warehouse=snowflake_warehouse,
    database=snowflake_database,
    schema=snowflake_schema,
    user=snowflake_user,
    password=snowflake_password,
    stage=snowflake_stage
)

# %%
def remove_extra_chars(text):
    # Remove extra characters like double quotes from the text
    return text.replace('"', '')

def sanitize_filename(filename):
    # Replace any dashes (-) with underscores (_) in the filename
    filename = filename.replace('-', '_')

    # Add 'S_' prefix if the filename starts with a number
    if filename[0].isdigit():
        filename = f"S_{filename}"

    return filename

def generate_unique_filename(filename):
    # Generate a unique filename to avoid overwriting existing files
    if not os.path.exists(filename):
        return filename
    base, ext = os.path.splitext(filename)
    count = 1
    while os.path.exists(f"{base}_{count}{ext}"):
        count += 1
    return f"{base}_{count}{ext}"

def sanitize_column_name(col):
    # Replace '%' with 'Percentage', '/' with 'Slash', and '+' with 'Plus'
    col = col.replace('%', 'Percentage').replace('/', 'Slash').replace('+', 'Plus')

    # Convert column names with numbers to English spelling
    words = col.split()
    new_words = []
    for word in words:
        try:
            num = w2n.word_to_num(word)
            new_words.append(str(num))
        except ValueError:
            new_words.append(word)
    col = ' '.join(new_words)

    return col

def handle_duplicate_columns(data):
    # Rename columns that have the same name by appending '_1', '_2', etc.
    header = data[0]
    header_count = {col: 1 for col in header}
    for i in range(1, len(header)):
        col = header[i]
        if header.count(col) > 1:
            data[0][i] = f"{col}_{header_count[col]}"
            header_count[col] += 1
    return data

def remove_empty_columns(data):
    # Remove any empty columns from the data
    return [[col for col in row if col] for row in data]

req = requests.get(URL)
soup = bs(req.text, 'html.parser')

links = soup.find_all('a', href=True)

for link in links:
    absolute_url = urljoin(URL, link['href'])
    req = requests.get(absolute_url)
    print(f"Visiting page: {absolute_url}...")  # Print statement with the URL being visited
    soup = bs(req.text, 'html.parser')

    table = soup.find('table')
    if table:
        data = []
        rows = table.find_all('tr')
        for row in rows:
            data.append([remove_extra_chars(cell.get_text(strip=True)) for cell in row.find_all('td')])

        if data:
            # Handle duplicate column names by appending '_1', '_2', etc.
            data = handle_duplicate_columns(data)

            # Remove empty columns from the data
            data = remove_empty_columns(data)

            # Create a unique CSV filename based on the page URL
            csv_filename = f"{sanitize_filename(os.path.basename(absolute_url))}.csv"
            csv_filename = generate_unique_filename(csv_filename)

            # Generate 'uuid' and 'LAST_UPDATE' values in real-time during scraping
            current_time = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
            data_with_new_columns = [['uuid', 'LAST_UPDATE'] + [sanitize_column_name(col) for col in data[0]]] + [[str(uuid.uuid4()), current_time] + [col for col in row] for row in data[1:]]

            # Save data to the CSV file
            with open(csv_filename, 'w', newline='', encoding='utf-8') as csvfile:
                writer = csv.writer(csvfile)
                writer.writerows(data_with_new_columns)

            # Upload the CSV file to Snowflake stage and replace the existing file
            cursor = conn.cursor()
            remove_command = f"REMOVE @{snowflake_stage}/{csv_filename}"
            cursor.execute(remove_command)
            put_command = f"PUT file://{csv_filename} @{snowflake_stage}/{csv_filename}"
            cursor.execute(put_command)
            cursor.close()

            print(f"Table data scraped and saved to '{csv_filename}' and uploaded to Snowflake stage.")
        else:
            print("No table data found on the page.")

    sleep(sleep_delay)

print("All links visited.")

# Close the Snowflake connection
conn.close()
# Out:
# Visiting page: https://www.espncricinfo.com/...
# Visiting page: https://www.espncricinfo.com/live-cricket-score...
# Visiting page: https://www.espncricinfo.com/ci/content/match/fixtures_futures.html...
# Visiting page: https://www.espncricinfo.com/team...
# Visiting page: https://www.espncricinfo.com/cricket-news...
# Visiting page: https://www.espncricinfo.com/cricket-features...
# Visiting page: https://www.espncricinfo.com/cricket-videos/...
# Visiting page: https://www.espncricinfo.com/records...
# Visiting page: https://www.espncricinfo.com/records...
# Visiting page: https://www.espncricinfo.com/records...
# Visiting page: https://www.espncricinfo.com/records/year/2023-2023...
# Visiting page: https://www.espncricinfo.com/ask...
# Visiting page: https://stats.espncricinfo.com/ci/engine/stats/index.html...
# Table data scraped and saved to 'index.html.csv' and uploaded to Snowflake stage.
# Visiting page: https://www.espncricinfo.com/records/trophy/world-cup-12...
# Visiting page: https://www.espncricinfo.com/records/trophy/icc-men-s-t20-world-cup-89...
# Visiting page: https://www.espncricinfo.com/records/tournament/indian-premier-league-2023-15129...
# Visiting page: https://www.espncricinfo.com/records/trophy/indian-premier-league-117...
# Visiting page: https://www.espncricinfo.com/records...
# Visiting page: https://www.espncricinfo.com/records/format/twenty20-internationals-3/category/team-records-2...
# Visiting page: https://www.espncricinfo.com/records/list-of-series-results-335433...
# Table data scraped and saved to 'list_of_series_results_335433.csv' and uploaded to Snowflake stage.
# Visiting page: https://www.espncricinfo.com/records/list-of-match-results-by-year-307852...
# Visiting page: https://www.espncricinfo.com/records/results-summary-283307...
# Table data scraped and saved to 'results_summary_283307.csv' and uploaded to Snowflake stage.
# Visiting page: https://www.espncricinfo.com/records/results-summary-by-opposition-283301...
# Table data scraped and saved to 'results_summary_by_opposition_283301.csv' and uploaded to Snowflake stage.
# Visiting page: https://www.espncricinfo.com/records/tied-matches-283291...
# Table data scraped and saved to 'tied_matches_283291.csv' and uploaded to Snowflake stage.
# Visiting page: https://www.espncricinfo.com/records/abandoned-matches-283285...
# Table data scraped and saved to 'abandoned_matches_283285.csv' and uploaded to Snowflake stage.
# Visiting page: https://www.espncricinfo.com/records/largest-margin-of-victory-by-runs-283283...
# Table data scraped and saved to 'largest_margin_of_victory_by_runs_283283.csv' and uploaded to Snowflake stage.
# Visiting page: https://www.espncricinfo.com/records/largest-margin-of-victory-by-wickets-283277...
# Table data scraped and saved to 'largest_margin_of_victory_by_wickets_283277.csv' and uploaded to Snowflake stage.
# Visiting page: https://www.espncricinfo.com/records/largest-margin-of-victory-by-balls-remaining-283270...
# Table data scraped and saved to 'largest_margin_of_victory_by_balls_remaining_283270.csv' and uploaded to Snowflake stage.
# Visiting page: https://www.espncricinfo.com/records/smallest-margin-of-victory-by-runs-283262...
# Table data scraped and saved to 'smallest_margin_of_victory_by_runs_283262.csv' and uploaded to Snowflake stage.
# Visiting page: https://www.espncricinfo.com/records/smallest-margin-of-victory-by-wickets-283252...
# Table data scraped and saved to 'smallest_margin_of_victory_by_wickets_283252.csv' and uploaded to Snowflake stage.
# Visiting page: https://www.espncricinfo.com/records
csv' and uploaded to Snowflake stage.
# Visiting page: https://www.espncricinfo.com/records/longest-intervals-between-appearances-1222956...
# Table data scraped and saved to 'longest_intervals_between_appearances_1222956.csv' and uploaded to Snowflake stage.
# Visiting page: https://www.espncricinfo.com/records/most-consecutive-matches-missed-for-a-team-between-appearances-323042...
# Table data scraped and saved to 'most_consecutive_matches_missed_for_a_team_between_appearances_323042.csv' and uploaded to Snowflake stage.
# Visiting page: https://www.espncricinfo.com/records/shortest-lived-players-1223144...
# Table data scraped and saved to 'shortest_lived_players_1223144.csv' and uploaded to Snowflake stage.
# Visiting page: https://www.espncricinfo.com/records/oldest-living-players-1223145...
# Table data scraped and saved to 'oldest_living_players_1223145.csv' and uploaded to Snowflake stage.
# Visiting page: https://www.espncricinfo.com/records/related-twenty20-international-players-312634...
# Table data scraped and saved to 'related_twenty20_international_players_312634.csv' and uploaded to Snowflake stage.
# Visiting page: https://www.espncricinfo.com/records/most-matches-as-captain-283428...
# Table data scraped and saved to 'most_matches_as_captain_283428.csv' and uploaded to Snowflake stage.
# Visiting page: https://www.espncricinfo.com/records/most-consecutive-matches-as-captain-of-a-team-1223146...
# Table data scraped and saved to 'most_consecutive_matches_as_captain_of_a_team_1223146.csv' and uploaded to Snowflake stage.
# Visiting page: https://www.espncricinfo.com/records/winning-all-tosses-in-a-series-1223147...
# Table data scraped and saved to 'winning_all_tosses_in_a_series_1223147.csv' and uploaded to Snowflake stage.
# Visiting page: https://www.espncricinfo.com/records/youngest-captains-283414...
# Table data scraped and saved to 'youngest_captains_283414.csv' and uploaded to Snowflake stage.
# Visiting page: https://www.espncricinfo.com/records/oldest-captains-on-captaincy-debut-323897...
# Table data scraped and saved to 'oldest_captains_on_captaincy_debut_323897.csv' and uploaded to Snowflake stage.
# Visiting page: https://www.espncricinfo.com/records/oldest-captains-283408...
# Table data scraped and saved to 'oldest_captains_283408.csv' and uploaded to Snowflake stage.
# Visiting page: https://www.espncricinfo.com/records/captains-who-have-kept-wicket-283402...
# Table data scraped and saved to 'captains_who_have_kept_wicket_283402.csv' and uploaded to Snowflake stage.
# Visiting page: https://www.espncricinfo.com/records/captains-who-have-kept-wicket-and-opened-the-batting-283396...
# Table data scraped and saved to 'captains_who_have_kept_wicket_and_opened_the_batting_283396.csv' and uploaded to Snowflake stage.
# Visiting page: https://www.espncricinfo.com/records/most-matches-as-an-umpire-283392...
# Table data scraped and saved to 'most_matches_as_an_umpire_283392.csv' and uploaded to Snowflake stage.
# Visiting page: https://www.espncricinfo.com/records/most-matches-as-a-match-referee-283386...
# Table data scraped and saved to 'most_matches_as_a_match_referee_283386.csv' and uploaded to Snowflake stage.
# Visiting page: https://www.espncricinfo.com/records/format/test-matches-1...
# Visiting page: https://www.espncricinfo.com/records/format/one-day-internationals-2...
# Visiting page: https://www.espncricinfo.com/records/format/twenty20-internationals-3...
# Visiting page: https://www.espncricinfo.com/records/format/first-class-matches-4...
# Visiting page: https://www.espncricinfo.com/records/format/list-a-matches-5...
# Visiting page: https://www.espncricinfo.com/records/format/twenty20-matches-6...
# Visiting page: https://www.espncricinfo.com/records/format/women-s-test-matches-8...
# Visiting page: https://www.espncricinfo.com/records/format/women-s-one-day-internationals-9...
# Visiting page: https://www.espncricinfo.com/records/format/women-s-twenty20-internationals-10...
# Visiting page: https://www.espncricinfo.com/records/format/combined-test-odi-and-t20i-records-11...
# Visiting page: https://www.espncricinfo.com/records/format/combined-first-class-list-a-and-twenty20-12...
# Visiting page: https://www.espncricinfo.com/records/format/all-cricket-records-including-minor-cricket-13...
# Visiting page: https://www.espncricinfo.com/records/format/under-19s-youth-test-matches-20...
# Visiting page: https://www.espncricinfo.com/records/format/under-19s-youth-one-day-internationals-21...
# Visiting page: https://disneytermsofuse.com/...
# Visiting page: https://privacy.thewaltdisneycompany.com/en/...
# Visiting page: https://preferences-mgr.truste.com/?type=espn&affiliateId=148...
# Visiting page: https://privacy.thewaltdisneycompany.com/en/current-privacy-policy/addendum-to-the-global-privacy-policy/...
# Visiting page: https://submit.espncricinfo.com/ci/content/submit/forms/feedback.html...
# Table data scraped and saved to 'feedback.html.csv' and uploaded to Snowflake stage.
# All links visited.
